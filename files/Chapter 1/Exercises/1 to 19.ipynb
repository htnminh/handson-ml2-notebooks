# %% [markdown]
# All my answers to exercises for Chapter 1 <br>
# <https://github.com/htnminh/handson-ml2-notebooks>

# %% [markdown]
# # 1. How would you define Machine Learning?

# %% [markdown]
# - Science: Programming computer $\Rightarrow$ Learn from data.
# - Field of study:
#     - Gives computer: Ability to learn
#     - Without explicitly programmed.
# - A program:
#     - Is said to:
#         - Learn from: experience E
#         - W.r.t:
#             - task T
#             - performance measure P
#     - If:
#         - Its performance on: T
#             - As measured by: P
#                 - Improve with: E

# %% [markdown]
# # 2. Can you name four types of problems where it shines?

# %% [markdown]
# Types of problems:
# - Existing solutions: require long rules.
# - Complex problem: no good solution.
# - Environments: fluctuates.
# - Insights:
#     - Complex problems
#     - Large amounts: data

# %% [markdown]
# # 3. What is a labeled training set?

# %% [markdown]
# A training set: includes desired solutions (labels) *for each instance*.

# %% [markdown]
# # 4. What are the two most common supervised tasks?

# %% [markdown]
# - Classification
# - Regression

# %% [markdown]
# # 5. Can you name four common unsupervised tasks?

# %% [markdown]
# - Clustering
# - Anomaly detection: ([Source](https://scikit-learn.org/stable/modules/outlier_detection.html))
#     - Outlier detection (the training data: contains outliers)
#     - Novelty detection (the training data: does not contain outliers)
# - Visualization & Dimensionality reduction
# - Association rule learning (discover relations: between attributes)

# %% [markdown]
# # 6. What type of Machine Learning algorithm would you use to allow a robot to walk in various unknown terrains?

# %% [markdown]
# *Reinforcement learning.*
#
# *Possible to use:*
# - *supervised learning*
# - *semisupervised learning*
#
# *But: less natural*

# %% [markdown]
# # 7. What type of algorithm would you use to segment your customers into multiple groups?

# %% [markdown]
# - Clustering*: if don't know how to define each group*
# - *Classification: else*

# %% [markdown]
# # 8. Would you frame the problem of spam detection as a supervised learning problem or an unsupervised learning problem?

# %% [markdown]
# Supervised

# %% [markdown]
# # 9. What is an online learning system?

# %% [markdown]
# Online learning (a.k.a. Incremental learning) system:
#
# - Train the system: incrementally
# - By: feeding data instances:
#     - sequentially
#         - individuals
#         - mini-batches
#     - each one is
#         - fast
#         - cheap
# - Can:
#     - learn: new data
#     - *train: large data*

# %% [markdown]
# # 10. What is out-of-core learning?
# An online training system that:
# - Huge datasets: cannot fit machine's memory
#     - Parts of data:
#         - Load
#         - Run: a training step
#         - Repeat: until run on all data

# %% [markdown]
# # 11. What type of learning algorithm relies on a similarity measure to make predictions?
# Instance-based

# %% [markdown]
# # 12. What is the difference between a model parameter and a learning algorithm’s hyperparameter?
# Model parameter (<https://machinelearningmastery.com/difference-between-a-parameter-and-a-hyperparameter/>):
# - Parameter: model configuration
# - Internal: model
# - Estimation *and optimize*: data
# - *Determine: prediction*
#
# Hyperparameter:
# - Parameter: learning algorithm
# - External: model
# - Constant: during training

# %% [markdown]
# # 13. What do model-based learning algorithms search for? What is the most common strategy they use to succeed? How do they make predictions?

# %% [markdown]
# Model-based learning
# - Search for: ~~maximum performance~~ *optimal value for model parameters $\Rightarrow$ generalize well*
# - Common strategy: run an algorithm to ~~find the "best" model parameters: on training data~~:
#     - Maximize: Utility function (a.k.a Fitness function)
#     - Minimize: Cost function
# - Make predictions: applying model on new instance*, using the parameters found*

# %% [markdown]
# # 14. Can you name four of the main challenges in Machine Learning?
# - Training data:
#     - insufficent quantity
#     - poor-quality
#     - nonrepresentative
# - Features: Irrelevant
# - Model:
#     - overfitting
#     - underfitting

# %% [markdown]
# # 15. If your model performs great on the training data but generalizes poorly to new instances, what is happening? Can you name three possible solutions?
# Overfitting:
# - Model: simplify:
#     - another model: fewer parameters
#     - training data: fewer attributes
#     - current model: constrain (regularization)
# - Training data:
#     - gather more
#     - reduce noise

# %% [markdown]
# # 16. What is a test set, and why would you want to use it?

# %% [markdown]
# Test set:
# - Splitted from data
# - Only used to test $\Rightarrow$ generalization error (out-of-sample error)

# %% [markdown]
# # 17. What is the purpose of a validation set?

# %% [markdown]
# Validation set:
# - Purpose: *Compare models:*
#     - Select model
#     - Tune hyperparameters
# - Usage:
#     - For every model:
#         - Train: (reduced) training set (excluding validation set)
#         - Validate: validation set
#     - Select: the best validated model:
#         - Train: (full) training set (including validation set)
#         - Test: test set

# %% [markdown]
# # 18. What is the train-dev set, when do you need it, and how do you use it?
# Train-dev set:
# - When to use: data mismatch between
#     - training set: nonrepresentative
#     - validation set and test set: representative
# - Definition:
#     - Splitted from: training set (excluding validation set)
#     - To conclude if: overfit or data mismatch
# - How to use:
#     - Train: training set (excluding validation set and train-dev set)
#     - *If model perform well on training set,* evaluate on train-dev set:
#         - poor: overfit
#         - well: not overfit
#             - Validate on validation set:
#                 - poor: data mismatch: try to preprocessing data, then retrain the model

# %% [markdown]
# # 19. What can go wrong if you tune hyperparameters using the test set?

# %% [markdown]
# The generalization error:
# - measured multiple times
# - on test set
#
# $\Rightarrow$ The best measured model:
# - adapted to that particular set
# - $\Rightarrow$ might not perform well: new data
#
# *(risk of overfitting, in short)*
